# %%
install.packages('data.table', 'ggplot2', 'plyr', 'xtable', dependencies=TRUE)
# Out:
# Warning message in install.packages("data.table", "ggplot2", "plyr", "xtable", dependencies = TRUE):
# “'lib = "ggplot2"' is not writable”
# Error in install.packages("data.table", "ggplot2", "plyr", "xtable", dependencies = TRUE): unable to install packages
# Traceback:
#
# 1. install.packages("data.table", "ggplot2", "plyr", "xtable", dependencies = TRUE)
# 2. stop("unable to install packages")
